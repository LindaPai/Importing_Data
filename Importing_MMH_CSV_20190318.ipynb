# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
file = "MMH Data Breakdown.csv"

# %%
data = pd.read_csv(file, sep= ",",nrows = 50, header =[1], na_values ="Nothing")  # Header = [0] will be "MMH Data Breakdown" title
data
# Out:
#     ID Initials   CRF Date Gender  Age  Weight (lb.)  Height (in.)  \
# 0    1      TCS   2016/3/8      M   76         145.2          65.0
# 1    2      KGS   2016/3/9      M   44         220.0          66.1
# 2    3      JAC   2016/3/9      F   67         133.8          57.1
# 3    4      LMS  2016/3/10      M   60         154.0          61.4
# 4    5      WMC  2016/3/10      M   49         154.0          67.7
# 5    6      LGF  2016/3/10      M   51         156.2          67.3
# 6    7      JWS  2016/3/16      M   64         145.2          64.2
# 7    8      JKS  2016/3/16      M   74         149.6          65.0
# 8    9      SGS  2016/3/17      M   74         140.1          70.1
# 9   10      HSI  2016/3/21      F   50         140.8          59.1
# 10  11      LIC  2016/3/22      M   56         135.3          61.8
# 11  12      LIM  2016/3/23      M   48         198.0          66.9
# 12  13      LIH  2016/3/28      F   59         123.2          63.4
# 13  14      LYE  2016/3/31      F   78         136.0          62.2
# 14  15      ISG  2016/3/31      F   73         114.4          59.4
# 15  16      JWJ  2016/3/31      M   49         171.6          68.1
# 16  17      SGW   2016/4/1      M   74         164.8          64.6
# 17  18      LGG   2016/4/6      M   52         165.0          67.7
# 18  19      HCG   2016/4/8      M   72         136.4          65.0
# 19  20      JLH  2016/4/11      F   67         122.8          58.7
# 20  21      GCG  2016/4/14      M   68         182.6          65.7
# 21  22      LGS  2016/4/14      M   48         189.2          70.1
# 22  23      SGS  2016/4/16      M   51         182.6          66.9
# 23  24      CCB  2016/4/19      M   60         149.6          66.5
# 24  25      LWS  2016/4/20      M   60         193.6          68.9
# 25  26      LGS  2016/4/21      M   73         154.0          59.8
# 26  27      SLG  2016/4/25      M   77         136.4          65.4
# 27  28      HSM   2016/5/3      F   85         130.5          60.6
# 28  29      JSL   2016/5/5      M   57         193.6          65.4
# 29  30      HTI   2016/5/7      M   52         151.8          65.7
# 30  31      JSS  2016/5/10      M   66         162.8          63.8
# 31  32      JYI  2016/5/18      F   75         140.8          59.4
# 32  33      LLT  2016/5/18      M   62         191.4          67.7
# 33  34      TGG  2016/5/31      M   59         149.6          64.6
# 34  35      LDW  2016/5/31      M   42         154.0          68.9
# 35  36      TGM   2016/6/1      M   63         162.8          68.1
# 36  37      TLS   2016/6/1      M   75         154.0          62.2
# 37  38      MGH   2016/6/1      F   50         143.0          62.2
# 38  39      KGG   2016/6/1      M   47         151.8          64.2
# 39  40      LIS   2016/6/2      M   55         191.4          65.4
# 40  41      IMG   2016/6/2      M   53         165.0          65.4
# 41  42      TJM   2016/6/2      M   47         206.8          66.5
# 42  43      LGI   2016/6/3      F   44         159.5          63.8
# 43  44      JYG   2016/6/3      F   41         198.0          66.1
# 44  45      SLM  2016/8/22      F   44         127.6          63.4
# 45  46      LAB  2016/8/22      F   76         112.2          58.7
# 46  47      GGF   2016/9/2      F   48         178.9          62.2
# 47  48      WWW  2016/9/21      M   58         147.4          64.2
# 48  49      IHG  2016/9/24      F   60         136.6          61.0
# 49  50      SWD  2016/10/4      M   69         185.5          67.3
#
#     CardioVue Date  CardioVue Result  Noise Level  \
# 0              NaN               NaN          NaN
# 1              NaN               NaN          NaN
# 2              NaN               NaN          NaN
# 3              NaN               NaN          NaN
# 4              NaN               NaN          NaN
# 5              NaN               NaN          NaN
# 6              NaN               NaN          NaN
# 7              NaN               NaN          NaN
# 8              NaN               NaN          NaN
# 9              NaN               NaN          NaN
# 10             NaN               NaN          NaN
# 11             NaN               NaN          NaN
# 12             NaN               NaN          NaN
# 13             NaN               NaN          NaN
# 14             NaN               NaN          NaN
# 15             NaN               NaN          NaN
# 16             NaN               NaN          NaN
# 17             NaN               NaN          NaN
# 18             NaN               NaN          NaN
# 19             NaN               NaN          NaN
# 20             NaN               NaN          NaN
# 21             NaN               NaN          NaN
# 22             NaN               NaN          NaN
# 23             NaN               NaN          NaN
# 24             NaN               NaN          NaN
# 25             NaN               NaN          NaN
# 26             NaN               NaN          NaN
# 27             NaN               NaN          NaN
# 28             NaN               NaN          NaN
# 29             NaN               NaN          NaN
# 30             NaN               NaN          NaN
# 31             NaN               NaN          NaN
# 32             NaN               NaN          NaN
# 33             NaN               NaN          NaN
# 34             NaN               NaN          NaN
# 35             NaN               NaN          NaN
# 36             NaN               NaN          NaN
# 37             NaN               NaN          NaN
# 38             NaN               NaN          NaN
# 39             NaN               NaN          NaN
# 40             NaN               NaN          NaN
# 41             NaN               NaN          NaN
# 42             NaN               NaN          NaN
# 43             NaN               NaN          NaN
# 44             NaN               NaN          NaN
# 45             NaN               NaN          NaN
# 46             NaN               NaN          NaN
# 47             NaN               NaN          NaN
# 48             NaN               NaN          NaN
# 49             NaN               NaN          NaN
#
#                   ...                 CCTA  CCTA Date  \
# 0                 ...                    N        NaN
# 1                 ...                    Y  2015/6/23
# 2                 ...                    N        NaN
# 3                 ...                    Y  2014/4/17
# 4                 ...                    N        NaN
# 5                 ...                    N        NaN
# 6                 ...                    N        NaN
# 7                 ...                    N        NaN
# 8                 ...                    N        NaN
# 9                 ...                    N        NaN
# 10                ...                    N        NaN
# 11                ...                    N        NaN
# 12                ...                    N        NaN
# 13                ...                    N        NaN
# 14                ...                    N        NaN
# 15                ...                    N        NaN
# 16                ...                    N        NaN
# 17                ...                    N        NaN
# 18                ...                    N        NaN
# 19                ...                    N        NaN
# 20                ...                    Y  2016/1/14
# 21                ...                    N        NaN
# 22                ...                    N        NaN
# 23                ...                    N        NaN
# 24                ...                    N        NaN
# 25                ...                    N        NaN
# 26                ...                    N        NaN
# 27                ...                    N        NaN
# 28                ...                    N        NaN
# 29                ...                    N        NaN
# 30                ...                    N        NaN
# 31                ...                    N        NaN
# 32                ...                    N        NaN
# 33                ...                    N        NaN
# 34                ...                    Y  2016/6/10
# 35                ...                    N        NaN
# 36                ...                    N        NaN
# 37                ...                    N        NaN
# 38                ...                    N        NaN
# 39                ...                    Y  2014/10/9
# 40                ...                    N        NaN
# 41                ...                    N        NaN
# 42                ...                    N        NaN
# 43                ...                    N        NaN
# 44                ...                    N        NaN
# 45                ...                    N        NaN
# 46                ...                    Y  2016/8/24
# 47                ...                    N        NaN
# 48                ...                    N        NaN
# 49                ...                    N        NaN
#
#                                          CCTA Results Angiogram  \
# 0                                                 NaN         Y
# 1                       Myocardial embedding of LAD-m         N
# 2                                                 NaN         N
# 3   1. high grade stenosis of LAD-p and D1 ostium\...         N
# 4                                                 NaN         N
# 5                                                 NaN         N
# 6                                                 NaN         N
# 7                                                 NaN         N
# 8                                                 NaN         Y
# 9                                                 NaN         Y
# 10                                                NaN         Y
# 11                                                NaN         Y
# 12                                                NaN         Y
# 13                                                NaN         Y
# 14                                                NaN         Y
# 15                                                NaN         N
# 16                                                NaN         Y
# 17                                                NaN         N
# 18                                                NaN         Y
# 19                                                NaN         Y
# 20  1. Calcified and partially calcified plaques a...         N
# 21                                                NaN         Y
# 22                                                NaN         N
# 23                                                NaN         Y
# 24                                                NaN         N
# 25                                                NaN         Y
# 26                                                NaN         Y
# 27                                                NaN         Y
# 28                                                NaN         N
# 29                                                NaN         N
# 30                                                NaN         Y
# 31                                                NaN         Y
# 32                                                NaN         N
# 33                                                NaN         Y
# 34  Noncalcified plaque at OM, with high grade ste...         Y
# 35                                                NaN         Y
# 36                                                NaN         Y
# 37                                                NaN         Y
# 38                                                NaN         Y
# 39  Noncalcified plaque at RCA-m with high grade s...         Y
# 40                                                NaN         Y
# 41                                                NaN         Y
# 42                                                NaN         Y
# 43                                                NaN         Y
# 44                                                NaN         Y
# 45                                                NaN         Y
# 46  RCA-m with high grade stenosis as well as calc...         Y
# 47                                                NaN         N
# 48                                                NaN         N
# 49                                                NaN         Y
#
#     Angiogram Date CardioVue CAD Result Angiogram Results  \
# 0         2016/3/8                  NaN                 Y
# 1              NaN                  NaN               NaN
# 2              NaN                  NaN               NaN
# 3              NaN                  NaN               NaN
# 4              NaN                  NaN               NaN
# 5              NaN                  NaN               NaN
# 6              NaN                  NaN               NaN
# 7              NaN                  NaN               NaN
# 8        2016/3/17                  NaN                 Y
# 9        2016/3/24                  NaN                 N
# 10       2016/3/22                  NaN                 Y
# 11       2016/3/24                  NaN                 ?
# 12       2016/3/28                  NaN                 Y
# 13       2016/3/31                  NaN                 Y
# 14       2010/2/21                  NaN                 Y
# 15             NaN                  NaN               NaN
# 16        2016/4/5                  NaN                 N
# 17             NaN                  NaN               NaN
# 18        2016/4/8                  NaN                 Y
# 19       2016/4/15                  NaN                 N
# 20             NaN                  NaN               NaN
# 21       2016/4/29                  NaN                 Y
# 22             NaN                  NaN               NaN
# 23       2016/4/19                  NaN                 N
# 24             NaN                  NaN               NaN
# 25       2016/5/20                  NaN                 Y
# 26       2016/4/25                  NaN                 Y
# 27        2016/5/4                  NaN                 Y
# 28             NaN                  NaN               NaN
# 29             NaN                  NaN               NaN
# 30       2016/5/10                  NaN                 Y
# 31       2016/5/26                  NaN                 N
# 32             NaN                  NaN               NaN
# 33       2016/6/16                  NaN                 N
# 34        2016/6/3                  NaN                 Y
# 35        2016/6/1                  NaN                 Y
# 36       2016/6/16                  NaN                 N
# 37       2016/6/23                  NaN                 N
# 38        2016/6/4                  NaN                 Y
# 39        2016/6/2                  NaN                 Y
# 40        2016/6/2                  NaN                 Y
# 41        2016/6/3                  NaN                 N
# 42        2016/6/3                  NaN                 N
# 43        2016/6/7                  NaN                 N
# 44       2016/8/25                  NaN                 ?
# 45       2016/8/26                  NaN                 Y
# 46        2016/9/2                  NaN                 Y
# 47             NaN                  NaN               NaN
# 48             NaN                  NaN               NaN
# 49       2016/10/4                  NaN                 Y
#
#                                           Unnamed: 30 Unnamed: 31  \
# 0   LM-d: 40%\nRCA-d: 85% stenosis\nLAD-p 50%\nLCX...         NaN
# 1                                                 NaN         NaN
# 2                                                 NaN         NaN
# 3                                                 NaN         NaN
# 4                                                 NaN         NaN
# 5                                                 NaN         NaN
# 6                                                 NaN         NaN
# 7                                                 NaN         NaN
# 8   RCA-PLV 80%\nLAD: -p 80%\nLCX: -p 30%, -m 50%,...         NaN
# 9                                  LAD-p 30% stenosis         NaN
# 10               RCA-d  90%\nLAD-p 40 -50%\nLCX-d 30%         NaN
# 11  Slow flow of both LCA and RCA without in-stent...         NaN
# 12  RCA-p to m luminal irregularity\nLAD: -p to m ...         NaN
# 13  RCA: -m 40%, -d 80%, -PDA 80%\nLAD: -m 80%, -d...         NaN
# 14  CAD, DVD\nLAD-d total occlusion with collatera...         NaN
# 15                                                NaN         NaN
# 16                                 LAD-d 50% stenosis         NaN
# 17                                                NaN         NaN
# 18                      LAD: -p-m 50%, -m 70%, -d 80%         NaN
# 19                            LAD-m: 30%\nLCX-OM: 30%         NaN
# 20                                                NaN         NaN
# 21                         RCA-P: 100%\nLAD-p-m: 100%         NaN
# 22                                                NaN         NaN
# 23                             LAD-d: 30%\nLCX-m: 30%         NaN
# 24                                                NaN         NaN
# 25  RCA: -p 30%, -d 70%, -PDA 80%\nLAD-D1: 90%\nLC...         NaN
# 26                                         LAD-p: 75%         NaN
# 27  LM-pn 40 - 50%\nRCA: -p 40 - 50%, -m 40 - 50%,...         NaN
# 28                                                NaN         NaN
# 29                                                NaN         NaN
# 30       RCA-p 100%\nLAD-p 100%\nLCX: -m 70%, -OM 95%         NaN
# 31                               RCA-p 30%\nLAD-m 30%         NaN
# 32                                                NaN         NaN
# 33           Slow flow of both LCA and RCA\nLCX-d 40%         NaN
# 34               LAD-m total occlusion\nLCX-d 20 -30%         NaN
# 35  LM-d 50%\nRCA-PDA 35%\nLAD: -p 70%, -d 40%, -D...         NaN
# 36        RCA: -m 50%, -PDA 50%\nLAD: -p 30%, -P1 50%         NaN
# 37                                 LAD-d 30% stenosis         NaN
# 38                  RCA-PLV 30%\nLAD-m 75%\nLCX-m 30%         NaN
# 39                               RCA-m 75%\nLAD-p 40%         NaN
# 40  LM-d 50%\nRCA: -m 30%, -PDA 80%, -PLV 50%\nLAD...         NaN
# 41          LAD-D 60%\nLCX: -d 40 - 50% ISR*, -m ISR*         NaN
# 42                               RCA-p 30%\nLAD-m 45%         NaN
# 43                               RCA-d 40%\nLCX-p 30%         NaN
# 44           Patent of coronary artery with slow flow         NaN
# 45  RCA-m 99%\nLAD-m 80%\nLCX: -p 30%, -OM 70%, -d...         NaN
# 46                    RCA-m 90%\nLAD-p 90%\nLCX-m 90%         NaN
# 47                                                NaN         NaN
# 48                                                NaN         NaN
# 49  RCA: -os 40%, -m 50%, -PDA 90%\nLAD-d 80%\nLCX...         NaN
#
#                          Unnamed: 32
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN
# 5                                NaN
# 6                                NaN
# 7                                NaN
# 8                                NaN
# 9                                NaN
# 10                               NaN
# 11                               NaN
# 12                               NaN
# 13                               NaN
# 14  * CTO -  chronic total occlusion
# 15          * BMS - bare metal stent
# 16         * DES: drug eluting stent
# 17      * DEB - drug eluting balloon
# 18                               NaN
# 19                               NaN
# 20                               NaN
# 21                               NaN
# 22                               NaN
# 23                               NaN
# 24                               NaN
# 25                               NaN
# 26                               NaN
# 27                               NaN
# 28                               NaN
# 29                               NaN
# 30                               NaN
# 31                               NaN
# 32                               NaN
# 33                               NaN
# 34                               NaN
# 35                               NaN
# 36                               NaN
# 37                               NaN
# 38                               NaN
# 39                               NaN
# 40       * ISR = in-stent restenosis
# 41                               NaN
# 42                               NaN
# 43                               NaN
# 44                               NaN
# 45                               NaN
# 46                               NaN
# 47                               NaN
# 48                               NaN
# 49                               NaN
#
# [50 rows x 33 columns]

# %%
data.columns
# Out:
# Index(['ID', 'Initials', 'CRF Date', 'Gender', 'Age', 'Weight (lb.)',
#        'Height (in.)', 'CardioVue Date', 'CardioVue Result', 'Noise Level',
#        'Sys. BP', 'ECG', 'ECG Date', 'Holter', 'Holter Date', 'Stress ECG',
#        'Stress ECG Date', 'Echo', 'Echo Date', 'SPECT', 'SPECT Date',
#        'SPECT Results', 'SPECT Result', 'CCTA', 'CCTA Date', 'CCTA Results',
#        'Angiogram', 'Angiogram Date', 'CardioVue CAD Result',
#        'Angiogram Results', 'Unnamed: 30', 'Unnamed: 31', 'Unnamed: 32'],
#       dtype='object')

# %%
df = data[["ID", "Gender","Age", 'Weight (lb.)','Height (in.)']]
df
# Out:
#     ID Gender  Age  Weight (lb.)  Height (in.)
# 0    1      M   76         145.2          65.0
# 1    2      M   44         220.0          66.1
# 2    3      F   67         133.8          57.1
# 3    4      M   60         154.0          61.4
# 4    5      M   49         154.0          67.7
# 5    6      M   51         156.2          67.3
# 6    7      M   64         145.2          64.2
# 7    8      M   74         149.6          65.0
# 8    9      M   74         140.1          70.1
# 9   10      F   50         140.8          59.1
# 10  11      M   56         135.3          61.8
# 11  12      M   48         198.0          66.9
# 12  13      F   59         123.2          63.4
# 13  14      F   78         136.0          62.2
# 14  15      F   73         114.4          59.4
# 15  16      M   49         171.6          68.1
# 16  17      M   74         164.8          64.6
# 17  18      M   52         165.0          67.7
# 18  19      M   72         136.4          65.0
# 19  20      F   67         122.8          58.7
# 20  21      M   68         182.6          65.7
# 21  22      M   48         189.2          70.1
# 22  23      M   51         182.6          66.9
# 23  24      M   60         149.6          66.5
# 24  25      M   60         193.6          68.9
# 25  26      M   73         154.0          59.8
# 26  27      M   77         136.4          65.4
# 27  28      F   85         130.5          60.6
# 28  29      M   57         193.6          65.4
# 29  30      M   52         151.8          65.7
# 30  31      M   66         162.8          63.8
# 31  32      F   75         140.8          59.4
# 32  33      M   62         191.4          67.7
# 33  34      M   59         149.6          64.6
# 34  35      M   42         154.0          68.9
# 35  36      M   63         162.8          68.1
# 36  37      M   75         154.0          62.2
# 37  38      F   50         143.0          62.2
# 38  39      M   47         151.8          64.2
# 39  40      M   55         191.4          65.4
# 40  41      M   53         165.0          65.4
# 41  42      M   47         206.8          66.5
# 42  43      F   44         159.5          63.8
# 43  44      F   41         198.0          66.1
# 44  45      F   44         127.6          63.4
# 45  46      F   76         112.2          58.7
# 46  47      F   48         178.9          62.2
# 47  48      M   58         147.4          64.2
# 48  49      F   60         136.6          61.0
# 49  50      M   69         185.5          67.3

# %%
bmi = (data["Weight (lb.)"].values / data["Height (in.)"].values / data["Height (in.)"].values) * 703

# %%
bmi = pd.DataFrame(bmi).rename(columns = {0 :"BMI"})

# %%
bmi.head()
# Out:
#          BMI
# 0  24.159905
# 1  35.397703
# 2  28.849562
# 3  28.717016
# 4  23.621023

# %%
df_concat = pd.concat([df,bmi], axis=1)

print(df_concat)
# Out:
#     ID Gender  Age  Weight (lb.)  Height (in.)        BMI
# 0    1      M   76         145.2          65.0  24.159905
# 1    2      M   44         220.0          66.1  35.397703
# 2    3      F   67         133.8          57.1  28.849562
# 3    4      M   60         154.0          61.4  28.717016
# 4    5      M   49         154.0          67.7  23.621023
# 5    6      M   51         156.2          67.3  24.244109
# 6    7      M   64         145.2          64.2  24.765773
# 7    8      M   74         149.6          65.0  24.892024
# 8    9      M   74         140.1          70.1  20.042755
# 9   10      F   50         140.8          59.1  28.338902
# 10  11      M   56         135.3          61.8  24.904405
# 11  12      M   48         198.0          66.9  31.100565
# 12  13      F   59         123.2          63.4  21.547035
# 13  14      F   78         136.0          62.2  24.712317
# 14  15      F   73         114.4          59.4  22.793366
# 15  16      M   49         171.6          68.1  26.012278
# 16  17      M   74         164.8          64.6  27.761792
# 17  18      M   52         165.0          67.7  25.308239
# 18  19      M   72         136.4          65.0  22.695669
# 19  20      F   67         122.8          58.7  25.054024
# 20  21      M   68         182.6          65.7  29.738931
# 21  22      M   48         189.2          70.1  27.067019
# 22  23      M   51         182.6          66.9  28.681632
# 23  24      M   60         149.6          66.5  23.781740
# 24  25      M   60         193.6          68.9  28.669640
# 25  26      M   73         154.0          59.8  30.274270
# 26  27      M   77         136.4          65.4  22.418895
# 27  28      F   85         130.5          60.6  24.981619
# 28  29      M   57         193.6          65.4  31.820367
# 29  30      M   52         151.8          65.7  24.722726
# 30  31      M   66         162.8          63.8  28.116960
# 31  32      F   75         140.8          59.4  28.053373
# 32  33      M   62         191.4          67.7  29.357558
# 33  34      M   59         149.6          64.6  25.201238
# 34  35      M   42         154.0          68.9  22.805395
# 35  36      M   63         162.8          68.1  24.678315
# 36  37      M   75         154.0          62.2  27.983065
# 37  38      F   50         143.0          62.2  25.984274
# 38  39      M   47         151.8          64.2  25.891490
# 39  40      M   55         191.4          65.4  31.458772
# 40  41      M   53         165.0          65.4  27.119631
# 41  42      M   47         206.8          66.5  32.874758
# 42  43      F   44         159.5          63.8  27.547022
# 43  44      F   41         198.0          66.1  31.857933
# 44  45      F   44         127.6          63.4  22.316572
# 45  46      F   76         112.2          58.7  22.891380
# 46  47      F   48         178.9          62.2  32.507599
# 47  48      M   58         147.4          64.2  25.141012
# 48  49      F   60         136.6          61.0  25.807525
# 49  50      M   69         185.5          67.3  28.791819

# %%
plt.plot(df_concat["Gender"],df_concat["BMI"])

# %%
plt.scatter(x =df_concat["BMI"] ,y = df_concat["Age"], s = np.array(bmi)*5, c = "green", alpha = 0.8)
#plt.xscale('log')
plt.xlabel("BMI")
plt.ylabel("Age")
plt.title("MMH Patients BMI Analysis")
plt.grid(True)

# %%
plt.hist(df_concat["BMI"], bins = 10)
plt.grid(True)
