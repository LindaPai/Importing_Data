# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
file = "MMH Data Breakdown.xlsx"

# %%
data = pd.ExcelFile(file)
df = pd.read_excel(file, "data info")

# %%
df
# Out:
#    MMH Data Breakdown Unnamed: 1           Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0                  ID   Initials             CRF Date     Gender        Age
# 1                   1        TCS  2016-03-08 00:00:00          M         76
# 2                   2        KGS  2016-03-09 00:00:00          M         44
# 3                   3        JAC  2016-03-09 00:00:00          F         67
# 4                   4        LMS  2016-03-10 00:00:00          M         60
# 5                   5        WMC  2016-03-10 00:00:00          M         49
# 6                   6        LGF  2016-03-10 00:00:00          M         51
# 7                   7        JWS  2016-03-16 00:00:00          M         64
# 8                   8        JKS  2016-03-16 00:00:00          M         74
# 9                   9        SGS  2016-03-17 00:00:00          M         74
# 10                 10        HSI  2016-03-21 00:00:00          F         50
# ...

# %%
data.sheet_names
# Out:
# ['data info', "key (don't change)", 'Test Dates Difference']

# %%
df.columns
# Out:
# Index(['MMH Data Breakdown', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3',
#        'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8',
#        'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12',
#        'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16',
#        'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20',
#        'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24',
#        'Unnamed: 25', 'Unnamed: 26', 'Unnamed: 27', 'Unnamed: 28',
#        'Unnamed: 29', 'Unnamed: 30', 'Unnamed: 31', 'Unnamed: 32'],
#       dtype='object')

# %%
df[0:4]
# Out:
#   MMH Data Breakdown Unnamed: 1           Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0                 ID   Initials             CRF Date     Gender        Age
# 1                  1        TCS  2016-03-08 00:00:00          M         76
# 2                  2        KGS  2016-03-09 00:00:00          M         44
# 3                  3        JAC  2016-03-09 00:00:00          F         67
#
#      Unnamed: 5    Unnamed: 6      Unnamed: 7        Unnamed: 8   Unnamed: 9  \
# 0  Weight (lb.)  Height (in.)  CardioVue Date  CardioVue Result  Noise Level
# 1         145.2       64.9606             NaN               NaN          NaN
# 2           220       66.1417             NaN               NaN          NaN
# 3        133.76       57.0866             NaN               NaN          NaN
#
#       ...     Unnamed: 23          Unnamed: 24                    Unnamed: 25  \
# 0     ...            CCTA            CCTA Date                   CCTA Results
# ...

# %%
Gen = df.iloc[1:,3]

# %%
Gen.name = "Gender"

# %%
Gen
# Out:
# 1     M
# 2     M
# 3     F
# 4     M
# 5     M
# 6     M
# 7     M
# 8     M
# 9     M
# 10    F
# 11    M
# 12    M
# 13    F
# 14    F
# 15    F
# 16    M
# 17    M
# 18    M
# 19    M
# 20    F
# 21    M
# 22    M
# 23    M
# 24    M
# 25    M
# 26    M
# 27    M
# 28    F
# 29    M
# 30    M
#      ..
# 34    M
# 35    M
# 36    M
# 37    M
# 38    F
# 39    M
# 40    M
# 41    M
# 42    M
# 43    F
# 44    F
# 45    F
# 46    F
# 47    F
# 48    M
# 49    F
# 50    M
# 51    M
# 52    M
# 53    M
# 54    M
# 55    M
# 56    F
# 57    F
# 58    M
# 59    M
# 60    F
# 61    M
# 62    F
# 63    F
# Name: Gender, Length: 63, dtype: object

# %%
Age = df.iloc[1:,4]
Age.name = "Age"
Age
# Out:
# 1     76
# 2     44
# 3     67
# 4     60
# 5     49
# 6     51
# 7     64
# 8     74
# 9     74
# 10    50
# 11    56
# 12    48
# 13    59
# 14    78
# 15    73
# 16    49
# 17    74
# 18    52
# 19    72
# 20    67
# 21    68
# 22    48
# 23    51
# 24    60
# 25    60
# 26    73
# 27    77
# 28    85
# 29    57
# 30    52
#       ..
# 34    59
# 35    42
# 36    63
# 37    75
# 38    50
# 39    47
# 40    55
# 41    53
# 42    47
# 43    44
# 44    41
# 45    44
# 46    76
# 47    48
# 48    58
# 49    60
# 50    69
# 51    65
# 52    53
# 53    65
# 54    63
# 55    51
# 56    73
# 57    66
# 58    75
# 59    59
# 60    63
# 61    64
# 62    38
# 63    60
# Name: Age, Length: 63, dtype: object

# %%
plt.plot(Gen, Age)
plt.show()

# %%
plt.scatter(Gen, Age)
plt.show()

# %%
plt.scatter(Age, Gen)
plt.show()

# %%
plt.hist(Gen)
plt.show()

# %%
plt.hist(Age)
plt.show()

# %%
# Rename a specific columns in a dataframe
data2 = df.rename(columns = {"Unnamed: 3" : "Gender"})
data2
# Out:
#    MMH Data Breakdown Unnamed: 1           Unnamed: 2  Gender Unnamed: 4  \
# 0                  ID   Initials             CRF Date  Gender        Age
# 1                   1        TCS  2016-03-08 00:00:00       M         76
# 2                   2        KGS  2016-03-09 00:00:00       M         44
# 3                   3        JAC  2016-03-09 00:00:00       F         67
# 4                   4        LMS  2016-03-10 00:00:00       M         60
# 5                   5        WMC  2016-03-10 00:00:00       M         49
# 6                   6        LGF  2016-03-10 00:00:00       M         51
# 7                   7        JWS  2016-03-16 00:00:00       M         64
# 8                   8        JKS  2016-03-16 00:00:00       M         74
# 9                   9        SGS  2016-03-17 00:00:00       M         74
# 10                 10        HSI  2016-03-21 00:00:00       F         50
# 11                 11        LIC  2016-03-22 00:00:00       M         56
# ...

# %%
data1 = df.iloc[1:,3:7]
data1
# Out:
#    Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6
# 1           M         76      145.2    64.9606
# 2           M         44        220    66.1417
# 3           F         67     133.76    57.0866
# 4           M         60        154    61.4173
# 5           M         49        154    67.7165
# 6           M         51      156.2    67.3228
# 7           M         64      145.2    64.1732
# 8           M         74      149.6    64.9606
# 9           M         74     140.14    70.0787
# 10          F         50      140.8    59.0551
# 11          M         56      135.3     61.811
# 12          M         48        198    66.9291
# 13          F         59      123.2    63.3858
# 14          F         78     135.96    62.2047
# 15          F         73      114.4    59.4488
# 16          M         49      171.6    68.1102
# 17          M         74     164.78    64.5669
# 18          M         52        165    67.7165
# 19          M         72      136.4    64.9606
# ...

# %%
data3 = data1.rename(columns = {"Unnamed: 3" : "Gender", "Unnamed: 4": "Age", "Unnamed: 5" : "Weight", "Unnamed: 6": "Height"})

# %%
data3.head()
# Out:
#   Gender Age  Weight   Height
# 1      M  76   145.2  64.9606
# 2      M  44     220  66.1417
# 3      F  67  133.76  57.0866
# 4      M  60     154  61.4173
# 5      M  49     154  67.7165
